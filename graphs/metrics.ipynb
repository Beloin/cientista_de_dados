# %% [markdown]
# # Métricas para ver seu Grafo

# %%
import igraph
from igraph import Graph, plot

# %%
grp = igraph.load('Grafo.graphml')
print(grp)
# Out:
# IGRAPH D-W- 53 179 --
# + attr: Handicapped (v), Lokationposition1highest53lowest (v), Repeater (v),
#   Sweetsgiver (v), b (v), g (v), id (v), label (v), r (v), size (v), x (v), y
#   (v), Edge Label (e), id (e), weight (e)
# + edges:
#  0 ->  3  4 36                              29 ->  0 13 45 49
#  1 -> 14 24 50                              30 -> 13 14 23 29 40
#  2 ->  1  3  8 15 35                        31 -> 35
#  3 ->  9 13 22 35 45 48                     32 -> 21 26
#  4 ->  0  5 13 23                           33 ->
#  5 ->  1  3  4 13                           34 ->  4
#  6 -> 10 15                                 35 ->  6 10 22 23 28 31 44 46 49
#  7 ->                                       36 -> 10 49
#  8 -> 40 49                                 37 ->  0  2 10 14 16 17 22 24 35
# 38 40 48
#  9 ->  3                                    38 -> 22 32 36
# 10 ->  6  8 13 14 27                        39 ->
# 11 -> 43                                    40 ->  8 12 20 23 50
# ...

# %%
plot(grp)

# %% [markdown]
# Gŕafico Social de uma rede social de amigos de uma faculdade

# %%
max(grp.degree(mode='all'))
# Out:
# 26

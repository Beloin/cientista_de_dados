# %% [markdown]
# # Grafos 2

# %%
from igraph import Graph, plot

# %%
grp = Graph()
grp.add_vertex()
grp.add_vertex()
grp.add_vertex()
grp.add_edges([(0,1), (1,2)])
plot(grp, bbox=(0,0,200,200))

# %%
grp.vs[0]['data'] = 'Thats True'

# %%
i = 1
for v in grp.vs:
    print(v)
    v['label'] = 'N°' + str(i)
    i+=1
# Out:
# igraph.Vertex(<igraph.Graph object at 0x7f823817b8b0>, 0, {'data': 'Thats True'})
# igraph.Vertex(<igraph.Graph object at 0x7f823817b8b0>, 1, {'data': None, 'label': None})
# igraph.Vertex(<igraph.Graph object at 0x7f823817b8b0>, 2, {'data': None, 'label': None})

# %%
plot(grp, bbox=(0,0,200,200))

# %% [markdown]
# Gerando pesos:

# %%
grp2 = Graph(edges=[(0,1), (1,2), (2,3)], directed=True)

# %%
plot(grp2, bbox=(0,0,250,30))

# %%
grp2.vs['label'] = ['Fernando', 'Pedro', 'Luiz', 'John']
grp2.vs['Peso_usuário'] = [57, 80, 67, 99, 101]

# %%
print(grp2)
# Out:
# IGRAPH D--- 4 3 --
# + attr: Peso_usuário (v), label (v)
# + edges:
# 0->1 1->2 2->3

# %%
plot(grp2, bbox=(0,0,400,250))

# %%
grp2.es['weight'] = [1,2,2,1]
print(grp2)
# Out:
# IGRAPH D-W- 4 3 --
# + attr: Peso_usuário (v), label (v), weight (e)
# + edges:
# 0->1 1->2 2->3

# %%
plot(grp2, bbox=(0,0,400,250))

# %%
for i in grp2.es:
    print(i)
# Out:
# igraph.Edge(<igraph.Graph object at 0x7f823817b6d0>, 0, {'weight': 1})
# igraph.Edge(<igraph.Graph object at 0x7f823817b6d0>, 1, {'weight': 2})
# igraph.Edge(<igraph.Graph object at 0x7f823817b6d0>, 2, {'weight': 2})

# %%
grp2.vs['name'] = 'Friendship level'
grp2.vs['type'] = 'Human'

# %%
print(grp2)
# Out:
# IGRAPH DNWT 4 3 --
# + attr: Peso_usuário (v), label (v), name (v), type (v), weight (e)
# + edges (vertex names):
# Friendship level->Friendship level, Friendship level->Friendship level,
# Friendship level->Friendship level

# %%
plot(grp2, bbox=(0,0,400,250))
